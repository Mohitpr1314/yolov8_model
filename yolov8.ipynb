# %% [markdown]
# # Modes
#              train,
#              val,
#              predict

# %% [markdown]
# #Task
#         detect,
#         segment,
#         classify

# %% [markdown]
# # Data
#                Format can differ for task type. Supports data.yaml, data_folder, dataset_name

# %%
# !nvidia-smi
# Out:
# Fri Sep 20 05:48:43 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# # SetUp

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.98 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.3/112.6 GB disk)

# %% [markdown]
# # 1. Predict

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=yolov8n.pt source='/content/mohitn.jpg'
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 357MB/s]
# Ultralytics YOLOv8.2.96 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/mohitn.jpg: 480x640 1 person, 40.2ms
# Speed: 13.6ms preprocess, 40.2ms inference, 751.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=yolov8n.pt source='/content/stock-photo-159533631.jpg'
# Out:
# Ultralytics YOLOv8.2.96 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/stock-photo-159533631.jpg: 448x640 2 persons, 59.2ms
# Speed: 4.7ms preprocess, 59.2ms inference, 1020.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=yolov8n.pt source='/content/images.jpg'
# Out:
# Ultralytics YOLOv8.2.96 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/images.jpg: 416x640 1 cat, 59.6ms
# Speed: 3.2ms preprocess, 59.6ms inference, 547.1ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=yolov8n.pt source='/content/images.jpg'
# Out:
# Ultralytics YOLOv8.2.94 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/images.jpg: 384x640 1 person, 44.8ms
# Speed: 3.0ms preprocess, 44.8ms inference, 572.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model=yolov8n.pt source='/content/bgg.jpg'
# Out:
# Ultralytics YOLOv8.2.94 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/bgg.jpg: 640x576 1 person, 40.6ms
# Speed: 4.1ms preprocess, 40.6ms inference, 632.0ms postprocess per image at shape (1, 3, 640, 576)
# Results saved to runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # Segmentation

# %%
# !yolo task=segment mode=predict model=yolov8n-seg.pt source='/content/mohitn.jpg'
# Out:
# ...
# 100% 6.74M/6.74M [00:00<00:00, 382MB/s]
# Ultralytics YOLOv8.2.96 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3,404,320 parameters, 0 gradients, 12.6 GFLOPs
#
# image 1/1 /content/mohitn.jpg: 480x640 1 person, 49.2ms
# Speed: 4.1ms preprocess, 49.2ms inference, 633.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=segment mode=predict model=yolov8n-seg.pt source='/content/stock-photo-159533631.jpg'
# Out:
# Ultralytics YOLOv8.2.96 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3,404,320 parameters, 0 gradients, 12.6 GFLOPs
#
# image 1/1 /content/stock-photo-159533631.jpg: 448x640 2 persons, 56.4ms
# Speed: 2.8ms preprocess, 56.4ms inference, 540.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/segment/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=segment mode=predict model=yolov8n-seg.pt source='/content/images.jpg'
# Out:
# Ultralytics YOLOv8.2.96 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3,404,320 parameters, 0 gradients, 12.6 GFLOPs
#
# image 1/1 /content/images.jpg: 416x640 1 cat, 56.0ms
# Speed: 3.3ms preprocess, 56.0ms inference, 610.8ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to runs/segment/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
#load a pretrained model yolov8 segmentation model
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')
model.predict(source='/content/mohitn.jpg', save=True)
# Out:
# image 1/1 /content/mohitn.jpg: 480x640 1 person, 48.3ms
# Speed: 4.0ms preprocess, 48.3ms inference, 600.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/segment/predict4
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
# ...

# %% [markdown]
# # Classification

# %%
# !yolo task=classify mode=predict model=yolov8n-cls.pt source='/content/mohitn.jpg'
# Out:
# ...
# 100% 5.31M/5.31M [00:00<00:00, 336MB/s]
# Ultralytics YOLOv8.2.96 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2,715,880 parameters, 0 gradients, 4.3 GFLOPs
#
# ...
# 100% 755k/755k [00:00<00:00, 83.6MB/s]
# image 1/1 /content/mohitn.jpg: 224x224 bath_towel 0.19, ping-pong_ball 0.08, shower_cap 0.06, stethoscope 0.06, bow_tie 0.05, 4.9ms
# Speed: 208.6ms preprocess, 4.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=classify mode=predict model=yolov8n-cls.pt source='/content/stock-photo-159533631.jpg'
# Out:
# Ultralytics YOLOv8.2.96 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2,715,880 parameters, 0 gradients, 4.3 GFLOPs
#
# image 1/1 /content/stock-photo-159533631.jpg: 224x224 vizsla 0.36, Chesapeake_Bay_retriever 0.19, redbone 0.11, Rhodesian_ridgeback 0.08, whippet 0.04, 3.9ms
# Speed: 27.8ms preprocess, 3.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !git clone https://github.com/Mohitpr1314/yolov8_model.git
# Out:
# Cloning into 'yolov8_model'...
# remote: Enumerating objects: 8731, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 8731 (delta 0), reused 3 (delta 0), pack-reused 8728 (from 1)
# Receiving objects: 100% (8731/8731), 292.48 MiB | 35.14 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# Updating files: 100% (9325/9325), done.

# %% [markdown]
# # Train your model on custom dataset

# %%
from ultralytics import YOLO

#load a pretrained model
# model = YOLO('yolov8n.pt')
model = YOLO()
model.train(data='/content/yolov8_model/furniture_dataset/data.yaml', epochs=25, imgsz=640)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 99.0MB/s]
# Ultralytics YOLOv8.2.98 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# train from cLI
# !yolo train data='/content/yolov8_model/furniture_dataset/data.yaml' epochs=25 imgsz=640

# %%
from ultralytics import YOLO

# Validate the new model directly using YOLO's API
model = YOLO('/content/runs/detect/train/weights/best.pt')
results = model.val(data='/content/yolov8_model/furniture_dataset/data.yaml')

# Display results
print(results)
# Out:
# Ultralytics YOLOv8.2.98 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,009,353 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/yolov8_model/furniture_dataset/valid/labels.cache... 507 images, 0 backgrounds, 0 corrupt: 100%|██████████| 507/507 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 12, len(boxes) = 661. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 32/32 [00:06<00:00,  4.88it/s]
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source='/content/intro-1653464053.jpg'
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-16-bffbf6e87994> in <cell line: 1>()
# ----> 1 get_ipython().system("yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source='/content/intro-1653464053.jpg'")
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
# ...

# %%
from ultralytics import YOLO

#load a pretrained model
model = YOLO('/content/runs/detect/train/weights/best.pt')
model.predict(source='/content/intro-1653464053.jpg', save=True)
# Out:
# image 1/1 /content/intro-1653464053.jpg: 384x640 1 Sofa, 94.5ms
# Speed: 3.6ms preprocess, 94.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Bed', 1: 'Chair', 2: 'Closet', 3: 'Computer', 4: 'Door', 5: 'Monitor', 6: 'Shelf', 7: 'Sofa', 8: 'Table', 9: 'Window', 10: 'Lamp', 11: 'ceiling-fan', 12: 'fork', 13: 'spoon', 14: 'clock', 15: 'fan', 16: 'glass', 17: 'Backpacks', 18: 'plate'}
#  obb: None
#  orig_img: array([[[171, 196, 216],
#          [174, 197, 223],
#          [171, 192, 223],
#          ...,
#          [246, 244, 244],
#          [246, 238, 239],
#          [242, 240, 239]],
#
#         [[ 93, 129, 117],
#          [102, 135, 128],
#          [121, 153, 148],
#          ...,
#          [246, 244, 244],
#          [246, 238, 239],
# ...

# %%
from ultralytics import YOLO

#load a pretrained model
model = YOLO('/content/runs/detect/train/weights/best.pt')
model.predict(source='/content/fur.webp', save=True)
# Out:
# image 1/1 /content/fur.webp: 480x640 1 Table, 37.8ms
# Speed: 1.5ms preprocess, 37.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Bed', 1: 'Chair', 2: 'Closet', 3: 'Computer', 4: 'Door', 5: 'Monitor', 6: 'Shelf', 7: 'Sofa', 8: 'Table', 9: 'Window', 10: 'Lamp', 11: 'ceiling-fan', 12: 'fork', 13: 'spoon', 14: 'clock', 15: 'fan', 16: 'glass', 17: 'Backpacks', 18: 'plate'}
#  obb: None
#  orig_img: array([[[153, 156, 169],
#          [153, 156, 169],
#          [153, 156, 169],
#          ...,
#          [168, 178, 190],
#          [168, 178, 190],
#          [168, 178, 190]],
#
#         [[153, 156, 169],
#          [153, 156, 169],
#          [153, 156, 169],
#          ...,
#          [168, 178, 190],
#          [168, 178, 190],
#          [168, 178, 190]],
#
# ...

# %% [markdown]
# ![fur.webp](data:image/webp;base64,...)

# %%
# %cd /content/yolov8_model
# Out:
# /content/yolov8_model
